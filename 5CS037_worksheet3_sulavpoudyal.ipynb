# %% [markdown]
# <a href="https://colab.research.google.com/github/salav2006poudyal2025/5CS037_worksheet1_sulavpoudyal/blob/main/5CS037_worksheet3_sulavpoudyal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 3 To- Do- Task
# Please Complete all the problem listed below.
# 3.1 Warm Up Exercises:
# 1. Sorting and Subsetting:
# Complete all following Task:
# Dataset for the Task: "titanic.csv"
# Following task is common for all the problem:
# 1. Load the provided dataset and import in pandas DataFrame.
# 2. Check info of the DataFrame and identify following:

# %%
# 1. Load the provided dataset and import in pandas DataFrame.
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/Dataset/Titanic-Dataset.csv")

# %%
# 2. Check info of the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# Problem 1- Sorting:
# 1. Create a DataFrame called fare that contains only the Fare column of the Titanic dataset. Print the head of the result.

# %%
# Problem 1 - Sorting

# 1. Create a DataFrame called fare that contains only the Fare column
fare = df[['Fare']]

# %%
# Print the head of the result
fare.head()
# Out:
#       Fare
# 0   7.2500
# 1  71.2833
# 2   7.9250
# 3  53.1000
# 4   8.0500

# %%
# 2. Create a DataFrame called class age that contains only the Pclass and Age columns of the Titanic dataset, in that order.
# Print the head of the result

# %%
# 2. Create a DataFrame called class_age with Pclass and Age columns (in that order)
class_age = df[['Pclass', 'Age']]

# %%
# Print the head of the result
class_age.head()
# Out:
#    Pclass   Age
# 0       3  22.0
# 1       1  38.0
# 2       3  26.0
# 3       1  35.0
# 4       3  35.0

# %%
# 3. Create a DataFrame called survived gender that contains the Survived and Sex columns of the Titanic dataset, in that order.
# Print the head of the result.

# %%
# 3. Create a DataFrame called survived_gender with Survived and Sex columns (in that order)
survived_gender = df[['Survived', 'Sex']]

# %%
# Print the head of the result
survived_gender.head()
# Out:
#    Survived     Sex
# 0         0    male
# 1         1  female
# 2         1  female
# 3         1  female
# 4         0    male

# %%
# Problem- 2- Subsetting:
# Complete all the following Task:
# Subsetting Rows

# %%
# 1. Filter the Titanic dataset for cases where the passenger’s fare is greater than 100, assigning it  to fare_gt_ 100.
# View the printed result.

# %%
# Filter Titanic dataset where Fare > 100
fare_gt_100 = df[df['Fare'] > 100]

# %%
# View the printed result
fare_gt_100
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 31            32         1       1
# 88            89         1       1
# 118          119         0       1
# 195          196         1       1
# 215          216         1       1
# 258          259         1       1
# 268          269         1       1
# 269          270         1       1
# 297          298         0       1
# 299          300         1       1
# 305          306         1       1
# 306          307         1       1
# 307          308         1       1
# 311          312         1       1
# 318          319         1       1
# 319          320         1       1
# 325          326         1       1
# 332          333         0       1
# 334          335         1       1
# 337          338         1       1
# 341          342         1       1
# 373          374         0       1
# 377          378         0       1
# 380          381         1       1
# ...

# %%
# 2. Filter the Titanic dataset for cases where the passenger’s class (Pclass) is 1, assigning it to first-class_passengers
# View the printed result.

# %%
# Filter Titanic dataset where Pclass == 1
first_class_passengers = df[df['Pclass'] == 1]

# %%
# View the printed result
first_class_passengers
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 3. Filter the Titanic dataset for cases where the passenger’s age is less than 18 and the passenger is female (Sex is "female"), assigning it to female
# under 18. View the printed result.

# %%
# Filter Titanic dataset for female passengers under age 18
female_under18 = df[(df['Age'] < 18) & (df['Sex'] == "female")]

# View the printed result
female_under18
# Out:
#      PassengerId  Survived  Pclass  \
# 9             10         1       2
# 10            11         1       3
# 14            15         0       3
# 22            23         1       3
# 24            25         0       3
# 39            40         1       3
# 43            44         1       2
# 58            59         1       2
# 68            69         1       3
# 71            72         0       3
# 84            85         1       2
# 111          112         0       3
# 114          115         0       3
# 119          120         0       3
# 147          148         0       3
# 156          157         1       3
# 172          173         1       3
# 184          185         1       3
# 205          206         0       3
# 208          209         1       3
# 233          234         1       3
# 237          238         1       2
# 297          298         0       1
# 307          308         1       1
# 329          330         1       1
# ...

# %%
# Subsetting Rows by Categorical variables:

# 1. Filter the Titanic dataset for passengers whose Embarked port is either "C" (Cherbourg) or "S"(Southampton), assigning the result to embarked
# c or s. View the printed result.

# %%
# 1. Filter Titanic dataset where Embarked is either "C" or "S"
embarked_c_or_s = df[df['Embarked'].isin(["C", "S"])]

# View the printed result
embarked_c_or_s
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 884          885         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 2. Filter the Titanic dataset for passengers whose Pclass is in the list [1, 2] (indicating first or second class), assigning the result to first
# secondclass.View the printed result

# %%
# 2. Filter Titanic dataset where Pclass is in [1, 2]
first_second_class = df[df['Pclass'].isin([1, 2])]

# View the printed result
first_second_class
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 9             10         1       2
# 11            12         1       1
# ..           ...       ...     ...
# 880          881         1       2
# 883          884         0       2
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 3.3 Exploratory Data Analysis with Group-by Method Practice Exercise:
# Based on the dataset Answer the following question:
# What percent of the total fare revenue came from each passenger class?
# To answer the question perform following operation:
# 1. Calculate the total Fare paid across all passengers in the Titanic dataset.
# 2. Subset for passengers in first class (Pclass is 1) and calculate their total fare.
# 3. Do the same for second class (Pclass is 2) and third class (Pclass is 3).
# 4. Combine the fare totals from first, second, and third classes into a list.
# 5. Divide the totals for each class by the overall total fare to get the proportion of fare revenue by class.

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/Dataset/Titanic-Dataset.csv")

# %%
# Calculate the total Fare paid by all passengers
total_fare = df['Fare'].sum()
total_fare
# Out:
# np.float64(28693.9493)

# %%
fare_first = df[df['Pclass'] == 1]['Fare'].sum()
fare_first
# Out:
# np.float64(18177.4125)

# %%
fare_second = df[df['Pclass'] == 2]['Fare'].sum()
fare_second
# Out:
# np.float64(3801.8417)

# %%
fare_third = df[df['Pclass'] == 3]['Fare'].sum()
fare_third
# Out:
# np.float64(6714.6951)

# %%
fare_totals = [fare_first, fare_second, fare_third]
fare_totals
# Out:
# [np.float64(18177.4125), np.float64(3801.8417), np.float64(6714.6951)]

# %%
fare_percentages = [(fare / total_fare) * 100 for fare in fare_totals]
fare_percentages
# Out:
# [np.float64(63.349287718996564),
#  np.float64(13.24962855496507),
#  np.float64(23.401083726038365)]

# %%
# What percent of the total number of passengers on the Titanic belonged to each age group
# (e.g., child, adult, senior)?
# To answer the question perform following operation:
# 1. Create a new column, age
# group, that categorizes passengers into "child" (age < 18), "adult" (age
# 18{64), and "senior" (age 65 and above).
# 2. Calculate the total number of passengers on the Titanic.
# 3. Count the number of passengers in each age group.
# 4. Divide the count of each age group by the total number of passengers to get the proportion of passengers
# in each age group.
# 5. Display the proportion as a percentage.

# %%
def categorize_age(age):
    if age < 18:
        return "child"
    elif age < 65:
        return "adult"
    else:
        return "senior"

df['age_group'] = df['Age'].apply(categorize_age)

# %%
total_passengers = len(df)
total_passengers
# Out:
# 891

# %%
age_group_counts = df['age_group'].value_counts()
age_group_counts
# Out:
# age_group
# adult     590
# senior    188
# child     113
# Name: count, dtype: int64

# %%
age_group_proportion = age_group_counts / total_passengers
age_group_proportion
# Out:
# age_group
# adult     0.662177
# senior    0.210999
# child     0.126824
# Name: count, dtype: float64

# %%
age_group_percentage = age_group_proportion * 100

for group, pct in age_group_percentage.items():
    print(f"{group}: {pct:.2f}%")
# Out:
# adult: 66.22%
# senior: 21.10%
# child: 12.68%
